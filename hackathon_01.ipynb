# %% [markdown]
# ### 데이터 경로 지정하기

# %%
import os
from os.path import join

data_dir = os.getenv('HOME')+'/aiffel/Hackathon_01/data'

train_path = join(data_dir, 'sales_train.csv')
test_path = join(data_dir, 'test.csv') 
items_path = join(data_dir, 'items.csv') 
item_categories_path = join(data_dir, 'item_categories.csv') 
shops_path = join(data_dir, 'shops.csv') 

print(train_path)
print(test_path)
print(items_path)
print(item_categories_path)
print(shops_path)
# Out:
# /home/aiffel-dj41/aiffel/Hackathon_01/data/sales_train.csv
# /home/aiffel-dj41/aiffel/Hackathon_01/data/test.csv
# /home/aiffel-dj41/aiffel/Hackathon_01/data/items.csv
# /home/aiffel-dj41/aiffel/Hackathon_01/data/item_categories.csv
# /home/aiffel-dj41/aiffel/Hackathon_01/data/shops.csv

# %% [markdown]
# ### 데이터 불러오기

# %%
import pandas as pd 

train_data = pd.read_csv(train_path)
test_data = pd.read_csv(test_path)
items_data = pd.read_csv(items_path)
item_categories_data = pd.read_csv(item_categories_path)
shops_data = pd.read_csv(shops_path)

train = pd.read_csv(train_path)
test = pd.read_csv(test_path)
items = pd.read_csv(items_path)
item_categories = pd.read_csv(item_categories_path)
shops = pd.read_csv(shops_path)

# %%
print('train data shape : {}'.format(train.shape))
print('test data shape : {}'.format(test.shape))
# Out:
# train data shape : (2935849, 6)
# test data shape : (214200, 3)

# %%
train
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %% [markdown]
# ### train 데이터에서 test 데이터에 없는 상품과 가게 없애기

# %%
print('train data shape : {}'.format(train.shape))

test_shops = test.shop_id.unique()
test_items = test.item_id.unique()

train = train[train.shop_id.isin(test_shops)]
train = train[train.item_id.isin(test_items)]

print('train data shape : {}'.format(train.shape))
# Out:
# train data shape : (2935849, 6)
# train data shape : (1224439, 6)

# %% [markdown]
# ### 중복 데이터 제거하기

# %%
print('train data shape : {}'.format(train.shape))

train.drop_duplicates(inplace=True, ignore_index = True)

train[train.duplicated()]

print('train data shape : {}'.format(train.shape))
# Out:
# train data shape : (1224439, 6)
# train data shape : (1224434, 6)

# %% [markdown]
# ### item_cnt_month 컬럼 추가하기

# %%
group = train.groupby(['date_block_num', 'shop_id', 'item_id']).agg({'item_cnt_day': ['sum']})

group.head()
# Out:
#                                item_cnt_day
#                                         sum
# date_block_num shop_id item_id
# 0              2       33               1.0
#                        482              1.0
#                        491              1.0
#                        839              1.0
#                        1007             3.0

# %%
group.columns = ['item_cnt_month']

group.head()
# Out:
#                                 item_cnt_month
# date_block_num shop_id item_id
# 0              2       33                  1.0
#                        482                 1.0
#                        491                 1.0
#                        839                 1.0
#                        1007                3.0

# %%
group.reset_index(inplace=True)

group.head()
# Out:
#    date_block_num  shop_id  item_id  item_cnt_month
# 0               0        2       33             1.0
# 1               0        2      482             1.0
# 2               0        2      491             1.0
# 3               0        2      839             1.0
# 4               0        2     1007             3.0

# %%
train = pd.merge(train, group, how='left')

print(len(train))
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  03.01.2013               0       25     2574       399.0           2.0
# 2  05.01.2013               0       25     2574       399.0           1.0
# 3  07.01.2013               0       25     2574       399.0           1.0
# 4  08.01.2013               0       25     2574       399.0           2.0
#
#    item_cnt_month
# 0             1.0
# 1            13.0
# 2            13.0
# 3            13.0
# 4            13.0

# %%
import numpy as np

train['item_cnt_month'] = (train['item_cnt_month'].fillna(0).clip(0, 30).astype(np.float16))

train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  03.01.2013               0       25     2574       399.0           2.0
# 2  05.01.2013               0       25     2574       399.0           1.0
# 3  07.01.2013               0       25     2574       399.0           1.0
# 4  08.01.2013               0       25     2574       399.0           2.0
#
#    item_cnt_month
# 0             1.0
# 1            13.0
# 2            13.0
# 3            13.0
# 4            13.0

# %% [markdown]
# ### year, month 컬럼 추가하기

# %%
year = train['date'].apply(lambda x : str(x[6:])).astype(int)
month = train['date'].apply(lambda x : str(x[3:5])).astype(int)

train = train.assign(year = year)
train = train.assign(month = month)

train
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154       999.0
# 1        03.01.2013               0       25     2574       399.0
# 2        05.01.2013               0       25     2574       399.0
# 3        07.01.2013               0       25     2574       399.0
# 4        08.01.2013               0       25     2574       399.0
# ...             ...             ...      ...      ...         ...
# 1224429  10.10.2015              33       25     7409       299.0
# 1224430  09.10.2015              33       25     7460       299.0
# 1224431  14.10.2015              33       25     7459       349.0
# 1224432  22.10.2015              33       25     7440       299.0
# 1224433  03.10.2015              33       25     7460       299.0
#
#          item_cnt_day  item_cnt_month  year  month
# 0                 1.0             1.0  2013      1
# 1                 2.0            13.0  2013      1
# 2                 1.0            13.0  2013      1
# 3                 1.0            13.0  2013      1
# 4                 2.0            13.0  2013      1
# ...               ...             ...   ...    ...
# 1224429           1.0             3.0  2015     10
# 1224430           1.0             3.0  2015     10
# 1224431           1.0             1.0  2015     10
# 1224432           1.0             1.0  2015     10
# 1224433           1.0             3.0  2015     10
#
# [1224434 rows x 9 columns]

# %% [markdown]
# ### city 컬럼 추가하기

# %%
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
city = shops["shop_name"].apply(lambda x: str.replace(x, '!', '')).apply(lambda x: x.split(' ')[0])

shops['city'] = pd.Categorical(city).codes

shops.drop('shop_name', axis=1, inplace=True)

shops.head()
# Out:
#    shop_id  city
# 0        0    29
# 1        1    29
# 2        2     0
# 3        3     1
# 4        4     2

# %%
print('train data shape : {}'.format(train.shape))

train = pd.merge(train, shops, on="shop_id", how="left")

print('train data shape : {}'.format(train.shape))
# Out:
# train data shape : (1224434, 9)
# train data shape : (1224434, 10)

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  03.01.2013               0       25     2574       399.0           2.0
# 2  05.01.2013               0       25     2574       399.0           1.0
# 3  07.01.2013               0       25     2574       399.0           1.0
# 4  08.01.2013               0       25     2574       399.0           2.0
#
#    item_cnt_month  year  month  city
# 0             1.0  2013      1    30
# 1            13.0  2013      1    13
# 2            13.0  2013      1    13
# 3            13.0  2013      1    13
# 4            13.0  2013      1    13

# %% [markdown]
# ### item_category_id1 컬럼 추가하기

# %%
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
items.drop('item_name', axis=1, inplace=True)

items.head()
# Out:
#    item_id  item_category_id
# 0        0                40
# 1        1                76
# 2        2                40
# 3        3                40
# 4        4                40

# %%
print('train data shape : {}'.format(train.shape))

train = pd.merge(train, items, on="item_id", how="left")

print('train data shape : {}'.format(train.shape))
# Out:
# train data shape : (1224434, 10)
# train data shape : (1224434, 11)

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  03.01.2013               0       25     2574       399.0           2.0
# 2  05.01.2013               0       25     2574       399.0           1.0
# 3  07.01.2013               0       25     2574       399.0           1.0
# 4  08.01.2013               0       25     2574       399.0           2.0
#
#    item_cnt_month  year  month  city  item_category_id
# 0             1.0  2013      1    30                37
# 1            13.0  2013      1    13                55
# 2            13.0  2013      1    13                55
# 3            13.0  2013      1    13                55
# 4            13.0  2013      1    13                55

# %% [markdown]
# ### item_category_id2 컬럼 추가하기

# %%
item_categories.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
item_category_id2 = item_categories['item_category_name'].apply(lambda x: str(x).split(' ')[0])

item_categories["item_category_id2"] = pd.Categorical(item_category_id2).codes

item_categories.drop('item_category_name', axis=1, inplace=True)

item_categories.head()
# Out:
#    item_category_id  item_category_id2
# 0                 0                  0
# 1                 1                  1
# 2                 2                  1
# 3                 3                  1
# 4                 4                  1

# %%
print('train data shape : {}'.format(train.shape))

train = pd.merge(train, item_categories, on="item_category_id", how="left")

print('train data shape : {}'.format(train.shape))
# Out:
# train data shape : (1224434, 11)
# train data shape : (1224434, 12)

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  03.01.2013               0       25     2574       399.0           2.0
# 2  05.01.2013               0       25     2574       399.0           1.0
# 3  07.01.2013               0       25     2574       399.0           1.0
# 4  08.01.2013               0       25     2574       399.0           2.0
#
#    item_cnt_month  year  month  city  item_category_id  item_category_id2
# 0             1.0  2013      1    30                37                  7
# 1            13.0  2013      1    13                55                  9
# 2            13.0  2013      1    13                55                  9
# 3            13.0  2013      1    13                55                  9
# 4            13.0  2013      1    13                55                  9

# %%
train.rename(columns = {"item_category_id" : "item_category_id1"}, inplace=True)

train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  03.01.2013               0       25     2574       399.0           2.0
# 2  05.01.2013               0       25     2574       399.0           1.0
# 3  07.01.2013               0       25     2574       399.0           1.0
# 4  08.01.2013               0       25     2574       399.0           2.0
#
#    item_cnt_month  year  month  city  item_category_id1  item_category_id2
# 0             1.0  2013      1    30                 37                  7
# 1            13.0  2013      1    13                 55                  9
# 2            13.0  2013      1    13                 55                  9
# 3            13.0  2013      1    13                 55                  9
# 4            13.0  2013      1    13                 55                  9

# %% [markdown]
# ### date 컬럼 삭제하기

# %%
train.drop('date', axis=1, inplace=True)

train.head()
# Out:
#    date_block_num  shop_id  item_id  item_price  item_cnt_day  item_cnt_month  \
# 0               0       59    22154       999.0           1.0             1.0
# 1               0       25     2574       399.0           2.0            13.0
# 2               0       25     2574       399.0           1.0            13.0
# 3               0       25     2574       399.0           1.0            13.0
# 4               0       25     2574       399.0           2.0            13.0
#
#    year  month  city  item_category_id1  item_category_id2
# 0  2013      1    30                 37                  7
# 1  2013      1    13                 55                  9
# 2  2013      1    13                 55                  9
# 3  2013      1    13                 55                  9
# 4  2013      1    13                 55                  9

# %%
train.tail()
# Out:
#          date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 1224429              33       25     7409       299.0           1.0
# 1224430              33       25     7460       299.0           1.0
# 1224431              33       25     7459       349.0           1.0
# 1224432              33       25     7440       299.0           1.0
# 1224433              33       25     7460       299.0           1.0
#
#          item_cnt_month  year  month  city  item_category_id1  \
# 1224429             3.0  2015     10    13                 55
# 1224430             3.0  2015     10    13                 55
# 1224431             1.0  2015     10    13                 55
# 1224432             1.0  2015     10    13                 57
# 1224433             3.0  2015     10    13                 55
#
#          item_category_id2
# 1224429                  9
# 1224430                  9
# 1224431                  9
# 1224432                  9
# 1224433                  9

# %% [markdown]
# ### test 데이터 똑같은 형태로 만들어주기

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
# date_block_num, year, month 추가하기

test['date_block_num'] = 34
test['year'] = 2015
test['month'] = 11

test.head()
# Out:
#    ID  shop_id  item_id  date_block_num  year  month
# 0   0        5     5037              34  2015     11
# 1   1        5     5320              34  2015     11
# 2   2        5     5233              34  2015     11
# 3   3        5     5232              34  2015     11
# 4   4        5     5268              34  2015     11

# %%
# city 컬럼 추가하기

test = pd.merge(test, shops, on="shop_id", how="left")

test.head()
# Out:
#    ID  shop_id  item_id  date_block_num  year  month  city
# 0   0        5     5037              34  2015     11     3
# 1   1        5     5320              34  2015     11     3
# 2   2        5     5233              34  2015     11     3
# 3   3        5     5232              34  2015     11     3
# 4   4        5     5268              34  2015     11     3

# %%
# item_category_id 컬럼 추가하기

test = pd.merge(test, items, on="item_id", how="left")

test.head()
# Out:
#    ID  shop_id  item_id  date_block_num  year  month  city  item_category_id
# 0   0        5     5037              34  2015     11     3                19
# 1   1        5     5320              34  2015     11     3                55
# 2   2        5     5233              34  2015     11     3                19
# 3   3        5     5232              34  2015     11     3                23
# 4   4        5     5268              34  2015     11     3                20

# %%
# item_category_id2 컬럼 추가하기

test = pd.merge(test, item_categories, on="item_category_id", how="left")

test.head()
# Out:
#    ID  shop_id  item_id  date_block_num  year  month  city  item_category_id  \
# 0   0        5     5037              34  2015     11     3                19
# 1   1        5     5320              34  2015     11     3                55
# 2   2        5     5233              34  2015     11     3                19
# 3   3        5     5232              34  2015     11     3                23
# 4   4        5     5268              34  2015     11     3                20
#
#    item_category_id2
# 0                  5
# 1                  9
# 2                  5
# 3                  5
# 4                  5

# %%
# 컬럼 변경하기

test.rename(columns = {"item_category_id" : "item_category_id1"}, inplace=True)

test.head()
# Out:
#    ID  shop_id  item_id  date_block_num  year  month  city  item_category_id1  \
# 0   0        5     5037              34  2015     11     3                 19
# 1   1        5     5320              34  2015     11     3                 55
# 2   2        5     5233              34  2015     11     3                 19
# 3   3        5     5232              34  2015     11     3                 23
# 4   4        5     5268              34  2015     11     3                 20
#
#    item_category_id2
# 0                  5
# 1                  9
# 2                  5
# 3                  5
# 4                  5

# %%
# ID 삭제하기

test.drop('ID', axis=1, inplace=True)

test.head()
# Out:
#    shop_id  item_id  date_block_num  year  month  city  item_category_id1  \
# 0        5     5037              34  2015     11     3                 19
# 1        5     5320              34  2015     11     3                 55
# 2        5     5233              34  2015     11     3                 19
# 3        5     5232              34  2015     11     3                 23
# 4        5     5268              34  2015     11     3                 20
#
#    item_category_id2
# 0                  5
# 1                  9
# 2                  5
# 3                  5
# 4                  5

# %% [markdown]
# ### train 데이터와 test 데이터 확인하기

# %%
y = train["item_cnt_month"]

train.drop('item_cnt_day', axis=1, inplace=True)
train.drop('item_cnt_month', axis=1, inplace=True)
train.drop('item_price', axis=1, inplace=True)

print(train.shape)
print(train.isnull().sum())

train.head()
# Out:
# (1224434, 8)
# date_block_num       0
# shop_id              0
# item_id              0
# year                 0
# month                0
# city                 0
# item_category_id1    0
# item_category_id2    0
# dtype: int64
#    date_block_num  shop_id  item_id  year  month  city  item_category_id1  \
# 0               0       59    22154  2013      1    30                 37
# 1               0       25     2574  2013      1    13                 55
# 2               0       25     2574  2013      1    13                 55
# 3               0       25     2574  2013      1    13                 55
# 4               0       25     2574  2013      1    13                 55
#
#    item_category_id2
# 0                  7
# 1                  9
# 2                  9
# 3                  9
# 4                  9

# %%
print(test.shape)
print(test.isnull().sum())

test.head()
# Out:
# (214200, 8)
# shop_id              0
# item_id              0
# date_block_num       0
# year                 0
# month                0
# city                 0
# item_category_id1    0
# item_category_id2    0
# dtype: int64
#    shop_id  item_id  date_block_num  year  month  city  item_category_id1  \
# 0        5     5037              34  2015     11     3                 19
# 1        5     5320              34  2015     11     3                 55
# 2        5     5233              34  2015     11     3                 19
# 3        5     5232              34  2015     11     3                 23
# 4        5     5268              34  2015     11     3                 20
#
#    item_category_id2
# 0                  5
# 1                  9
# 2                  5
# 3                  5
# 4                  5

# %%
from lightgbm import LGBMRegressor

random_state=2021

lightgbm = LGBMRegressor(max_depth=10,
                         learning_rate=0.05,
                         num_iterations=1000,
                         boosting="gbdt",
                         random_state=random_state)
      
lightgbm.fit(train, y)

y_pred = lightgbm.predict(test)
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %%
y_pred
# Out:
# array([-4.45921753,  0.2487092 , -4.45921753, ..., -0.03434449,
#         0.5135434 , -0.82575714])

# %%
test_data["item_cnt_month"] = y_pred

sub = test_data.loc[:, ["ID", "item_cnt_month"]]

sub
# Out:
#             ID  item_cnt_month
# 0            0       -4.459218
# 1            1        0.248709
# 2            2       -4.459218
# 3            3       -3.581143
# 4            4        1.014904
# ...        ...             ...
# 214195  214195       -0.034344
# 214196  214196       -0.054176
# 214197  214197       -0.034344
# 214198  214198        0.513543
# 214199  214199       -0.825757
#
# [214200 rows x 2 columns]

# %%
sub_csv_path = data_dir + "/{}.csv".format("lightgbm")
sub.to_csv(sub_csv_path, index=False)
